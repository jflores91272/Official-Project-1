# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r'/Users/jonathanflores/Documents/Flatiron/Gitted_project/zippedData/tn.movie_budgets.csv')
df
# Out:
#       id  release_date                                        movie  \
# 0      1  Dec 18, 2009                                       Avatar
# 1      2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2      3   Jun 7, 2019                                 Dark Phoenix
# 3      4   May 1, 2015                      Avengers: Age of Ultron
# 4      5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# ...   ..           ...                                          ...
# 5777  78  Dec 31, 2018                                       Red 11
# 5778  79   Apr 2, 1999                                    Following
# 5779  80  Jul 13, 2005                Return to the Land of Wonders
# 5780  81  Sep 29, 2015                         A Plague So Pleasant
# 5781  82   Aug 5, 2005                            My Date With Drew
#
#      production_budget domestic_gross worldwide_gross
# 0         $425,000,000   $760,507,625  $2,776,345,279
# ...

# %%
df['production_budget'] =df['production_budget'].apply(lambda x: x.replace('$',' '))
df['domestic_gross'] =df['domestic_gross'].apply(lambda x: x.replace('$',' '))
df['worldwide_gross'] =df['worldwide_gross'].apply(lambda x: x.replace('$',' '))
df['production_budget'] =df['production_budget'].apply(lambda x: x.replace(',',' '))
df['domestic_gross'] =df['domestic_gross'].apply(lambda x: x.replace(',',' '))
df['worldwide_gross'] =df['worldwide_gross'].apply(lambda x: x.replace(',',' '))
df
# Out:
#       id  release_date                                        movie  \
# 0      1  Dec 18, 2009                                       Avatar
# 1      2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2      3   Jun 7, 2019                                 Dark Phoenix
# 3      4   May 1, 2015                      Avengers: Age of Ultron
# 4      5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# ...   ..           ...                                          ...
# 5777  78  Dec 31, 2018                                       Red 11
# 5778  79   Apr 2, 1999                                    Following
# 5779  80  Jul 13, 2005                Return to the Land of Wonders
# 5780  81  Sep 29, 2015                         A Plague So Pleasant
# 5781  82   Aug 5, 2005                            My Date With Drew
#
#      production_budget domestic_gross worldwide_gross     budget  \
# 0          425 000 000    760 507 625   2 776 345 279  425000000
# ...

# %%
df['budget']= df['production_budget'].str.replace(' ', '')
df
# Out:
#       id  release_date                                        movie  \
# 0      1  Dec 18, 2009                                       Avatar
# 1      2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2      3   Jun 7, 2019                                 Dark Phoenix
# 3      4   May 1, 2015                      Avengers: Age of Ultron
# 4      5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# ...   ..           ...                                          ...
# 5777  78  Dec 31, 2018                                       Red 11
# 5778  79   Apr 2, 1999                                    Following
# 5779  80  Jul 13, 2005                Return to the Land of Wonders
# 5780  81  Sep 29, 2015                         A Plague So Pleasant
# 5781  82   Aug 5, 2005                            My Date With Drew
#
#      production_budget domestic_gross worldwide_gross     budget
# 0          425 000 000    760 507 625   2 776 345 279  425000000
# ...

# %%
df['Domesticgross']=df['domestic_gross'].str.replace(' ', '')
df['WorldWidegross']=df['worldwide_gross'].str.replace(' ', '')
df
# Out:
#       id  release_date                                        movie  \
# 0      1  Dec 18, 2009                                       Avatar
# 1      2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2      3   Jun 7, 2019                                 Dark Phoenix
# 3      4   May 1, 2015                      Avengers: Age of Ultron
# 4      5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# ...   ..           ...                                          ...
# 5777  78  Dec 31, 2018                                       Red 11
# 5778  79   Apr 2, 1999                                    Following
# 5779  80  Jul 13, 2005                Return to the Land of Wonders
# 5780  81  Sep 29, 2015                         A Plague So Pleasant
# 5781  82   Aug 5, 2005                            My Date With Drew
#
#      production_budget domestic_gross worldwide_gross     budget  \
# 0          425 000 000    760 507 625   2 776 345 279  425000000
# ...

# %%
df2 = df.drop(['production_budget', 'domestic_gross'], axis=1)

# %%
df2
# Out:
#       id  release_date                                        movie  \
# 0      1  Dec 18, 2009                                       Avatar
# 1      2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2      3   Jun 7, 2019                                 Dark Phoenix
# 3      4   May 1, 2015                      Avengers: Age of Ultron
# 4      5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# ...   ..           ...                                          ...
# 5777  78  Dec 31, 2018                                       Red 11
# 5778  79   Apr 2, 1999                                    Following
# 5779  80  Jul 13, 2005                Return to the Land of Wonders
# 5780  81  Sep 29, 2015                         A Plague So Pleasant
# 5781  82   Aug 5, 2005                            My Date With Drew
#
#      worldwide_gross     budget Domesticgross WorldWidegross
# 0      2 776 345 279  425000000     760507625     2776345279
# ...

# %%
df2["budget"] = pd.to_numeric(df["budget"], downcast="float")

# %%
df2.dtypes
# Out:
# id                   int64
# release_date        object
# movie               object
# worldwide_gross     object
# budget             float64
# Domesticgross       object
# WorldWidegross      object
# dtype: object

# %%
df2["WorldWidegross"] = pd.to_numeric(df["WorldWidegross"], downcast="float")

# %%
df2.dtypes
# Out:
# id                   int64
# release_date        object
# movie               object
# worldwide_gross     object
# budget             float64
# Domesticgross       object
# WorldWidegross     float64
# dtype: object

# %%
df2["ProfitMargin"] = df2["WorldWidegross"]/df2["budget"]
df2
# Out:
#       id  release_date                                        movie  \
# 0      1  Dec 18, 2009                                       Avatar
# 1      2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2      3   Jun 7, 2019                                 Dark Phoenix
# 3      4   May 1, 2015                      Avengers: Age of Ultron
# 4      5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# ...   ..           ...                                          ...
# 5777  78  Dec 31, 2018                                       Red 11
# 5778  79   Apr 2, 1999                                    Following
# 5779  80  Jul 13, 2005                Return to the Land of Wonders
# 5780  81  Sep 29, 2015                         A Plague So Pleasant
# 5781  82   Aug 5, 2005                            My Date With Drew
#
#      worldwide_gross       budget Domesticgross  WorldWidegross  ProfitMargin
# ...

# %%
df2['ProfitMargin'] = df2['ProfitMargin'].apply(lambda x: x*100)

# %%
df10=df2.sort_values(['ProfitMargin'], ascending=True)
df10.head(60)
# Out:
#       id  release_date                                              movie  \
# 5712  13  Dec 31, 2012                                            Hayride
# 5753  54  Dec 31, 2014                                          Dry Spell
# 2754  55   Mar 8, 2016                                 Out of the Inferno
# 5318  19  Feb 10, 2015                                        Fear Clinic
# 5319  20  Mar 10, 2015                                            The Pet
# 5593  94  Dec 31, 2010                                The Christmas Bunny
# 2011  12  Dec 31, 2003                                      Ripley's Game
# 5472  73   Apr 3, 2012                                      Enter Nowhere
# 5320  21  Dec 31, 2014                                     Bang Bang Baby
# 3162  63  Jun 29, 2001                                       Pandaemonium
# 5321  22   Apr 8, 2016                                               Hush
# 5322  23   Mar 1, 2016                                               1982
# ...

# %%
df3 = df2.sort_values(['WorldWidegross'], ascending=False)
df3.head(16)
# Out:
#      id  release_date                                          movie  \
# 0     1  Dec 18, 2009                                         Avatar
# 42   43  Dec 19, 1997                                        Titanic
# 5     6  Dec 18, 2015           Star Wars Ep. VII: The Force Awakens
# 6     7  Apr 27, 2018                         Avengers: Infinity War
# 33   34  Jun 12, 2015                                 Jurassic World
# 66   67   Apr 3, 2015                                      Furious 7
# 26   27   May 4, 2012                                   The Avengers
# 3     4   May 1, 2015                        Avengers: Age of Ultron
# 41   42  Feb 16, 2018                                  Black Panther
# 260  61  Jul 15, 2011  Harry Potter and the Deathly Hallows: Part II
# 4     5  Dec 15, 2017              Star Wars Ep. VIII: The Last Jedi
# 112  13  Jun 22, 2018                 Jurassic World: Fallen Kingdom
# 155  56  Nov 22, 2013                                         Frozen
# ...

# %%
df4 = df3.head(16)

# %%
df4.sort_values(['budget','WorldWidegross'], ascending=[False,False])
# Out:
#      id  release_date                                          movie  \
# 0     1  Dec 18, 2009                                         Avatar
# 3     4   May 1, 2015                        Avengers: Age of Ultron
# 4     5  Dec 15, 2017              Star Wars Ep. VIII: The Last Jedi
# 5     6  Dec 18, 2015           Star Wars Ep. VII: The Force Awakens
# 6     7  Apr 27, 2018                         Avengers: Infinity War
# 22   23  Apr 14, 2017                        The Fate of the Furious
# 26   27   May 4, 2012                                   The Avengers
# 33   34  Jun 12, 2015                                 Jurassic World
# 42   43  Dec 19, 1997                                        Titanic
# 41   42  Feb 16, 2018                                  Black Panther
# 43   44  Jun 15, 2018                                  Incredibles 2
# 66   67   Apr 3, 2015                                      Furious 7
# 112  13  Jun 22, 2018                 Jurassic World: Fallen Kingdom
# ...

# %%
ax = sns.scatterplot(x = 'movie', y = 'ProfitMargin',hue = 'budget', data = df4)
ax.tick_params(axis='x', labelrotation = 90)
sns.move_legend(ax,"upper left", bbox_to_anchor=(1, 1))
sns.color_palette("magma", as_cmap=True)

plt.show()

# %%
ax=sns.barplot(data=df4, x="movie", y="ProfitMargin")
ax.tick_params(axis='x', labelrotation = 90)

# %%
A24 = pd.read_csv(r'/Users/jonathanflores/Documents/Flatiron/Gitted_project/A24.csv')
A24
# Out:
#      Unnamed: 0                                          title  \
# 0             0  A Glimpse Inside the Mind of Charles Swan III
# 1             1                                  Ginger & Rosa
# 2             2                                Spring Breakers
# 3             3                                 The Bling Ring
# 4             4                            The Spectacular Now
# ..          ...                                            ...
# 147         147                                 Dream Scenario
# 148         148                              I Saw the TV Glow
# 149         149                                  The Iron Claw
# 150         150                                      Priscilla
# 151         151                                        Tuesday
#
#            Directed by         Written by  \
# 0        Roman Coppola      Roman Coppola
# 1         Sally Potter       Sally Potter
# 2       Harmony Korine     Harmony Korine
# ...

# %%
A24.drop(['Produced by', 'Starring', 'Cinematography','Edited by','Music by','Production companies'], axis=1)
A25 = A24

# %%
A26= A25.drop(['Release dates (datetime)','rotten_tomatoes','Screenplay by','Based on','Produced by','Starring','Cinematography','Edited by','Music by','Production companies','Language','Running time (int)','Country','Distributed by','Written by','Unnamed: 0'], axis=1)
A26
# Out:
#                                              title        Directed by  \
# 0    A Glimpse Inside the Mind of Charles Swan III      Roman Coppola
# 1                                    Ginger & Rosa       Sally Potter
# 2                                  Spring Breakers     Harmony Korine
# 3                                   The Bling Ring      Sofia Coppola
# 4                              The Spectacular Now     James Ponsoldt
# ..                                             ...                ...
# 147                                 Dream Scenario  Kristoffer Borgli
# 148                              I Saw the TV Glow    Jane Schoenbrun
# 149                                  The Iron Claw        Sean Durkin
# 150                                      Priscilla      Sofia Coppola
# 151                                        Tuesday     Daina O. Pusic
#
#      Budget (float)  Box office (float)  imdb  metascore
# 0               NaN            210565.0   4.6       28.0
# ...

# %%
A26["ProfitMargin"] = A26["Box office (float)"]/A26["Budget (float)"]
A26
# Out:
#                                              title        Directed by  \
# 0    A Glimpse Inside the Mind of Charles Swan III      Roman Coppola
# 1                                    Ginger & Rosa       Sally Potter
# 2                                  Spring Breakers     Harmony Korine
# 3                                   The Bling Ring      Sofia Coppola
# 4                              The Spectacular Now     James Ponsoldt
# ..                                             ...                ...
# 147                                 Dream Scenario  Kristoffer Borgli
# 148                              I Saw the TV Glow    Jane Schoenbrun
# 149                                  The Iron Claw        Sean Durkin
# 150                                      Priscilla      Sofia Coppola
# 151                                        Tuesday     Daina O. Pusic
#
#      Budget (float)  Box office (float)  imdb  metascore  ProfitMargin
# ...

# %%
A26['ProfitMargin'] = A26['ProfitMargin'].apply(lambda x: x*100)
A26
# Out:
#                                              title        Directed by  \
# 0    A Glimpse Inside the Mind of Charles Swan III      Roman Coppola
# 1                                    Ginger & Rosa       Sally Potter
# 2                                  Spring Breakers     Harmony Korine
# 3                                   The Bling Ring      Sofia Coppola
# 4                              The Spectacular Now     James Ponsoldt
# ..                                             ...                ...
# 147                                 Dream Scenario  Kristoffer Borgli
# 148                              I Saw the TV Glow    Jane Schoenbrun
# 149                                  The Iron Claw        Sean Durkin
# 150                                      Priscilla      Sofia Coppola
# 151                                        Tuesday     Daina O. Pusic
#
#      Budget (float)  Box office (float)  imdb  metascore  ProfitMargin
# ...

# %%
A26.sort_values(['ProfitMargin'], ascending=False)
# Out:
#                  title        Directed by  Budget (float)  Box office (float)  \
# 41           Moonlight      Barry Jenkins       1500000.0          65300000.0
# 51       A Ghost Story       David Lowery        100000.0           2000000.0
# 122                  X            Ti West       1000000.0          15100000.0
# 114                  X            Ti West       1000000.0          15100000.0
# 28           The Witch      Robert Eggers       4000000.0          40400000.0
# ..                 ...                ...             ...                 ...
# 147     Dream Scenario  Kristoffer Borgli             NaN                 NaN
# 148  I Saw the TV Glow    Jane Schoenbrun             NaN                 NaN
# 149      The Iron Claw        Sean Durkin             NaN                 NaN
# 150          Priscilla      Sofia Coppola             NaN                 NaN
# 151            Tuesday     Daina O. Pusic             NaN                 NaN
#
# ...

# %%
A27 = A26.dropna()

# %%
A28 = A27.sort_values(['ProfitMargin'], ascending=False)
A28.head(25)
# Out:
#                                  title                          Directed by  \
# 41                           Moonlight                        Barry Jenkins
# 51                       A Ghost Story                         David Lowery
# 122                                  X                              Ti West
# 114                                  X                              Ti West
# 28                           The Witch                        Robert Eggers
# 121                              Pearl                              Ti West
# 50                   It Comes at Night                   Trey Edward Shults
# 67                          Hereditary                            Ari Aster
# 57                           Lady Bird                         Greta Gerwig
# 101                             Minari                      Lee Isaac Chung
# 86                        The Farewell                            Lulu Wang
# ...

# %%
A29=A28.drop(114)
A29
# Out:
#                          title                          Directed by  \
# 41                   Moonlight                        Barry Jenkins
# 51               A Ghost Story                         David Lowery
# 122                          X                              Ti West
# 28                   The Witch                        Robert Eggers
# 121                      Pearl                              Ti West
# ..                         ...                                  ...
# 68           Woman Walks Ahead                        Susanna White
# 54                   Woodshock  ['Kate Mulleavy', 'Laura Mulleavy']
# 60   The Ballad of Lefty Brown                          Jared Moshe
# 129                White Noise                        Noah Baumbach
# 59                    The Room                         Tommy Wiseau
#
#      Budget (float)  Box office (float)  imdb  metascore  ProfitMargin
# 41        1500000.0          65300000.0   7.4       99.0   4353.333333
# ...

# %%
A30=A29.head(11)
A30
# Out:
#                                  title                          Directed by  \
# 41                           Moonlight                        Barry Jenkins
# 51                       A Ghost Story                         David Lowery
# 122                                  X                              Ti West
# 28                           The Witch                        Robert Eggers
# 121                              Pearl                              Ti West
# 50                   It Comes at Night                   Trey Edward Shults
# 67                          Hereditary                            Ari Aster
# 57                           Lady Bird                         Greta Gerwig
# 101                             Minari                      Lee Isaac Chung
# 86                        The Farewell                            Lulu Wang
# 115  Everything Everywhere All at Once  ['Daniel Kwan', 'Daniel Scheinert']
#
# ...

# %%
ax = sns.scatterplot(x = 'title', y = 'ProfitMargin',hue = 'Budget (float)', data = A30)
ax.tick_params(axis='x', labelrotation = 90)
sns.move_legend(ax,"upper left", bbox_to_anchor=(1, 1))
sns.color_palette("magma", as_cmap=True)
plt.show()

# %%
ax=sns.barplot(data=A30, x="title", y="ProfitMargin")
ax.tick_params(axis='x', labelrotation = 90)

# %%
A30 = A24.sort_values(by='metascore', ascending=False)
A31= A30.head(30)
A31.dtypes
# Out:
# Unnamed: 0                    int64
# title                        object
# Directed by                  object
# Written by                   object
# Produced by                  object
# Starring                     object
# Cinematography               object
# Edited by                    object
# Music by                     object
# Production companies         object
# Distributed by               object
# Country                      object
# Language                     object
# Running time (int)          float64
# Budget (float)              float64
# Box office (float)          float64
# Release dates (datetime)     object
# imdb                        float64
# metascore                   float64
# rotten_tomatoes              object
# Screenplay by                object
# Based on                     object
# dtype: object

# %%
ax = sns.scatterplot(x = 'Directed by', y = 'metascore', data= A31)

ax.tick_params(axis='x', labelrotation = 90)

plt.show()

# %%
ax=sns.scatterplot(x='title', y='metascore', hue='Directed by', data=A31)
ax.tick_params(axis='x', labelrotation = 90)
sns.move_legend(ax,"upper left", bbox_to_anchor=(1, 1))


plt.show()

# %%
df.to_csv(r'', index=False)
